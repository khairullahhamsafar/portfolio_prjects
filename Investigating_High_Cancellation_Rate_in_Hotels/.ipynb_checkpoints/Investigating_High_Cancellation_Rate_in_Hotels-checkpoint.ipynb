# %% [markdown]
# <a id="header"></a>
# <div style="border: 1px solid; color: #0d4987; background-color: #1163ff;">
#     <center><img src="img/hotal_banner_01.jpg"></center>
#     <div style="border: 5px solid; color: #ededed; border-radius: 5px; margin: 10px; padding: 15px;">
#         <h1 style="font-size: 26px; color: #ededed; text-align: center; font-family: Blogger Sans; font-weight: bold; line-height: 28px;">
#         &#128269; Investigating High Cancellation Rate in Hotels &#127976;
#         </h1>
#         <h1 style="font-size: 26px; color: #ededed; text-align: center; font-family: Blogger Sans; font-weight: bold; line-height: 28px;">
#         &#128300; Research-based Analysis for Countering High Cancellation Rates. &#128202;
#         </h1>
#     </div>
# </div>

# %% [markdown]
# <div style="border: 1px solid; color: #19a01a; background-color: #ededed;">
#     <div style="border: 1px solid; color: #19a01a; background-color: #42ba00;">
#         <h1 style="font-size: 26px; color: #fff600; text-align: justify; font-family: Blogger Sans; font-weight: bold; margin: 10px; border: 5px solid; border-radius: 5px; padding: 15px;">
#     &#128221; Table of Content
#         </h1>
#     </div>
# <ol>
#     <li style="font-size: 20px; color: #42ba00; text-align: justify; text-decoration: none; font-family: Calibri (Body); margin: 20px;">
#         <a style="text-decoration: none; color: #42ba00; cursor: pointer;" href="#1">Introduction</a>
#     </li>
#     <li style="font-size: 20px; color: #42ba00; text-align: justify; text-decoration: none; font-family: Calibri (Body); margin: 20px;">
#         <a style="text-decoration: none; color: #42ba00; cursor: pointer;" href="#2">Business Problem and Assumptions</a>
#     </li>
#     <li style="font-size: 20px; color: #42ba00; text-align: justify; text-decoration: none; font-family: Calibri (Body); margin: 20px;">
#         <a style="text-decoration: none; color: #42ba00; cursor: pointer;" href="#3">Research Questions and Hypothesis</a>
#     </li>
#     <li style="font-size: 20px; color: #42ba00; text-align: justify; text-decoration: none; font-family: Calibri (Body); margin: 20px;">
#         <a style="text-decoration: none; color: #42ba00; cursor: pointer;" href="#4">Loading Data and Libraries</a>
#     </li>
#     <li style="font-size: 20px; color: #42ba00; text-align: justify; text-decoration: none; font-family: Calibri (Body); margin: 20px;">
#         <a style="text-decoration: none; color: #42ba00; cursor: pointer;" href="#5">Data Cleaning and Preprocessing</a>
#     </li>
#     <li style="font-size: 20px; color: #42ba00; text-align: justify; text-decoration: none; font-family: Calibri (Body); margin: 20px;">
#         <a style="text-decoration: none; color: #42ba00; cursor: pointer;" href="#6">Analysis and Findings</a>
#     </li>
#     <li style="font-size: 20px; color: #42ba00; text-align: justify; text-decoration: none; font-family: Calibri (Body); margin: 20px;">
#         <a style="text-decoration: none; color: #42ba00; cursor: pointer;" href="#7">Suggested Data-driven Decisions</a>
#     </li>
#     <li style="font-size: 20px; color: #42ba00; text-align: justify; text-decoration: none; font-family: Calibri (Body); margin: 20px;">
#         <a style="text-decoration: none; color: #42ba00; cursor: pointer;" href="#8">Author Message</a>
#     </li>
# </ol>
# </div>

# %% [markdown]
# <a id="1"></a>
# <h1 style="background-color: #ffe500; font-size: 26px; color: #363021; text-align: center; font-family: Blogger Sans; font-weight: bold; margin: 10px; border: 1px solid; border-color: #363021; border-radius: 1px; padding: 15px; border-radius: 8px 8px 0 0;">1. Introduction</h1>

# %% [markdown]
# <a id="1.1"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff;">1.1. About Data</h2>

# %% [markdown]
# <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
# The dataset, sourced from Mustafa's Kaggle profile, provides information on hotel reservations with 1,19,390 observations for a City Hotel and a Resort Hotel. Each observation represents a hotel booking between the 1st of July 2015 and 31st of August 2017, including booking that effectively arrived and booking that were canceled. It has been tailored for analysis by excluding features deemed irrelevant. Additionally, preprocessing steps have been applied to enhance data quality, including the handling of missing values and removal of outliers. For further more detailed information, please visit my <a style="text-decoration: none; color: #e81123; cursor: pointer;" href="https://www.kaggle.com/datasets/khairullahhamsafar/hotels-booking-data-cleaned-version" target="_blank">Kaggle Profile</a>.</p>

# %% [markdown]
# <a id="2"></a>
# <h1 style="background-color: #ffe500; font-size: 26px; color: #363021; text-align: center; font-family: Blogger Sans; font-weight: bold; margin: 10px; border: 1px solid; border-color: #363021; border-radius: 1px; padding: 15px; border-radius: 8px 8px 0 0;">2. Business Problem and Assumptions</h1>

# %% [markdown]
# <a id="2.1"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff;">2.1. Business Problem</h2>

# %% [markdown]
# <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">In recent years, both Resort Hotel and City Hotel have faced significant challenges due to high cancellation rates, leading to issues such as reduced revenues and suboptimal room utilization. The primary cause of suboptimal room usage is the elevated cancellation rates, resulting in decreased revenue generation. Lowering cancellation rates is crucial for both hotels to enhance efficiency and revenue.</p>
# <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #19a01a;">As a data analyst's, our responsibility is to provide comprehensive business advice to address this pressing issue. The focus of this report is on analyzing hotel booking cancellations and identifying other factors unrelated to their business that may impact yearly revenue generation.</p>

# %% [markdown]
# <a id="2.2"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff;">2.2. Assumptions</h2>

# %% [markdown]
# <ul style="margin: 12px 0px 0px 12px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#     <li style="font-size: 18px; padding-bottom: 10px;">No significant outliers affected the data between 2015 and 2017.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">The information remains current for efficient hotel analysis.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">No unexpected negative consequences are anticipated if hotels implement advised techniques.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">The suggested solutions are not currently in use by the hotels.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">The primary factor impacting income effectiveness is booking cancellations.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">Cancellations lead to vacant rooms for the reserved time, hindering potential earnings.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">Clients make hotel reservations and cancellations within the same year.</li>
# </ul>

# %% [markdown]
# <a id="3"></a>
# <h1 style="background-color: #ffe500; font-size: 26px; color: #363021; text-align: center; font-family: Blogger Sans; font-weight: bold; margin: 10px; border: 1px solid; border-color: #363021; border-radius: 1px; padding: 15px; border-radius: 8px 8px 0 0;">3. Research Questions and Hypothesis</h1>

# %% [markdown]
# <a id="3.1"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff;">3.1. Research Questions</h2>

# %% [markdown]
# <ol style="margin: 12px 0px 0px 12px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#     <li style="font-size: 18px; padding-bottom: 10px;">Which features (variables) influence the cancellation of hotel bookings (room reservations)?</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">What strategies can enhance the efficiency of hotel booking (room reservation) processes?</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">In what ways can hotels receive support for pricing and promotional decision-making?</li>
# </ol>

# %% [markdown]
# <a id="3.2"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff;">3.2. Hypotheses</h2>

# %% [markdown]
# <ol style="margin: 12px 0px 0px 12px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#     <li style="font-size: 18px; padding-bottom: 10px;">Higher prices contribute to an increased number of cancellations.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">A lengthier waiting list correlates with higher customer cancellation rates.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">The majority of clients opt for reservations through offline travel agents.</li>
# </ol>

# %% [markdown]
# <a id="4"></a>
# <h1 style="background-color: #ffe500; font-size: 26px; color: #363021; text-align: center; font-family: Blogger Sans; font-weight: bold; margin: 10px; border: 1px solid; border-color: #363021; border-radius: 1px; padding: 15px; border-radius: 8px 8px 0 0;">4. Loading Data and Libraries</h1>

# %% [markdown]
# <a id="4.1"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">4.1. Importing Necessary Libraries</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="4.2"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">4.2. Loading Data</h2>

# %%
hotelsData = pd.read_csv('Dataset/hotel_booking_data_cleaned.csv')

# %% [markdown]
# <a id="4.3"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">4.3. Creating DataFrame</h2>

# %%
df = pd.DataFrame(hotelsData)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              01/07/2015
# 1              01/07/2015
# 2              02/07/2015
# 3              02/07/2015
# 4              03/07/2015
#
# [5 rows x 32 columns]

# %% [markdown]
# <a id="5"></a>
# <h1 style="background-color: #ffe500; font-size: 26px; color: #363021; text-align: center; font-family: Blogger Sans; font-weight: bold; margin: 10px; border: 1px solid; border-color: #363021; border-radius: 1px; padding: 15px; border-radius: 8px 8px 0 0;">5. Data Cleaning and Preprocessing</h1>

# %% [markdown]
# <a id="5.1"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">5.1. Concise Summary</h2>

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
# <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">By default, our important coulmn 'reservation_status_date' is in object (categorical) data type. Let's to change its data type to 'dateTime'.</p>

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(16), object(11)
# memory usage: 29.1+ MB

# %% [markdown]
# <a id="5.2"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">5.2. Checking Columns</h2>

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# <a id="5.3"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">5.3. Extracting Columns Having Object Data Types</h2>

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print('_'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# __________________________________________________
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# __________________________________________________
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# __________________________________________________
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
#  'NPL' 'BHS' 'MAC' 'TGO' 'TWN' 'DJI' 'STP' 'KNA' 'ETH' 'IRQ' 'HND' 'RWA'
#  'KHM' 'MCO' 'BGD' 'IMN' 'TJK' 'NIC' 'BEN' 'VGB' 'TZA' 'GAB' 'GHA' 'TMP'
#  'GLP' 'KEN' 'LIE' 'GNB' 'MNE' 'UMI' 'MYT' 'FRO' 'MMR' 'PAN' 'BFA' 'LBY'
#  'MLI' 'NAM' 'BOL' 'PRY' 'BRB' 'ABW' 'AIA' 'SLV' 'DMA' 'PYF' 'GUY' 'LCA'
#  'ATA' 'GTM' 'ASM' 'MRT' 'NCL' 'KIR' 'SDN' 'ATF' 'SLE' 'LAO']
# __________________________________________________
# market_segment
# ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# __________________________________________________
# distribution_channel
# ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# __________________________________________________
# reserved_room_type
# ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# __________________________________________________
# assigned_room_type
# ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# __________________________________________________
# deposit_type
# ['No Deposit' 'Refundable' 'Non Refund']
# __________________________________________________
# customer_type
# ['Transient' 'Contract' 'Transient-Party' 'Group']
# __________________________________________________
# reservation_status
# ['Check-Out' 'Canceled' 'No-Show']
# __________________________________________________

# %% [markdown]
# <a id="5.4"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">5.4. Handling Missing Values</h2>

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         We observe a significant number of missing values in the 'agent' and 'company' columns, suggesting that dropping these columns might be a valuable decision. Other techniques for handling missing values may not be feasible or effective in this context.
#     </p>
# </div>

# %%
df.drop(['agent', 'company'], axis = 1, inplace = True)

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Now, the 'country' column contains 488 null entries. Therefore, it is advisable to drop these null entries.
#     </p>
# </div>

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# dtype: int64

# %% [markdown]
# <a id="5.5"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">5.5. Statistical Summary</h2>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Typically, we employ the 'describe' function to obtain a statistical summary of numerical data. However, its 'include' parameter allows us to retrieve a statistical summary of object or categorical data types as well.
#     </p>
# </div>

# %%
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       118898             118898  118898  118898         118898
# unique           2                 12       5     177              7
# top     City Hotel             August      BB     PRT      Online TA
# freq         79302              13852   91863   48586          56402
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                118898             118898             118898
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97730              85601              73863
#
#        deposit_type customer_type reservation_status
# count        118898        118898             118898
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104163         89174              74745

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Let's explore the statistical summary of numerical data to identify potential outliers.
#     </p>
# </div>

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
# std                   13.589971                   8.780324
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            118898.000000         118898.000000  118898.000000
# mean                  0.928897              2.502145       1.858391
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  16.000000             41.000000      55.000000
# std                   0.996216              1.900168       0.578576
#
#             children         babies  is_repeated_guest  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.104207       0.007948           0.032011
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         0.000000       0.000000           0.000000
# 75%         0.000000       0.000000           0.000000
# max        10.000000      10.000000           1.000000
# std         0.399172       0.097380           0.176029
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           118898.000000                   118898.000000
# mean                 0.087142                        0.131634
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
# std                  0.845869                        1.484672
#
#        booking_changes  days_in_waiting_list            adr  \
# count    118898.000000         118898.000000  118898.000000
# mean          0.221181              2.330754     102.003243
# min           0.000000              0.000000      -6.380000
# 25%           0.000000              0.000000      70.000000
# 50%           0.000000              0.000000      95.000000
# 75%           0.000000              0.000000     126.000000
# max          21.000000            391.000000    5400.000000
# std           0.652785             17.630452      50.485862
#
#        required_car_parking_spaces  total_of_special_requests  \
# count                118898.000000              118898.000000
# mean                      0.061885                   0.571683
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000
# std                       0.244172                   0.792678
#
#              reservation_status_date
# count                         118898
# mean   2016-07-30 07:37:53.336809984
# min              2014-10-17 00:00:00
# 25%              2016-02-02 00:00:00
# 50%              2016-08-08 00:00:00
# 75%              2017-02-09 00:00:00
# max              2017-09-14 00:00:00
# std                              NaN

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         We can see a lot of outliers exist in the data. But we need to handle only one feature 'average daily rate (adr)' outlier. Feature 'adr' contain an outlier of 5400, which are neccessory to be removed. Let's to plot in a box.
#     </p>
# </div>

# %%
adr_outlier = df.copy()

# %%
plt.rc('font', size=12)
plt.rc('axes', labelcolor='#fff600')
plt.rc('text', color='#fff600')
plt.rc('xtick', color='#fff600')

myFig, ax = plt.subplots(figsize=(8, 6))
myFig.set_facecolor('#e81123')

with sns.axes_style("whitegrid"):
    sns.boxplot(x=adr_outlier['adr'], color='#1163ff', fliersize=5, linewidth=3, saturation=0.95, width=0.3, ax=ax)

plt.xlabel('Average Daily Rate (ADR)', labelpad=20)
plt.title('Box Plot: Outlier in ADR', fontsize=20, pad=20)

plt.show()

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Let's remove it.
#     </p>
# </div>

# %%
adr_outlier_removed = df[df['adr'] < 5000].copy()

# %%
adr_outlier_removed.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
# std                   13.589966                   8.780321
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            118897.000000         118897.000000  118897.000000
# mean                  0.928905              2.502157       1.858390
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  16.000000             41.000000      55.000000
# std                   0.996217              1.900171       0.578578
#
#             children         babies  is_repeated_guest  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.104208       0.007948           0.032011
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         0.000000       0.000000           0.000000
# 75%         0.000000       0.000000           0.000000
# max        10.000000      10.000000           1.000000
# std         0.399174       0.097381           0.176030
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           118897.000000                   118897.000000
# mean                 0.087143                        0.131635
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
# std                  0.845872                        1.484678
#
#        booking_changes  days_in_waiting_list            adr  \
# count    118897.000000         118897.000000  118897.000000
# mean          0.221175              2.330774     101.958683
# min           0.000000              0.000000      -6.380000
# 25%           0.000000              0.000000      70.000000
# 50%           0.000000              0.000000      95.000000
# 75%           0.000000              0.000000     126.000000
# max          21.000000            391.000000     510.000000
# std           0.652784             17.630525      48.091199
#
#        required_car_parking_spaces  total_of_special_requests  \
# count                118897.000000              118897.000000
# mean                      0.061885                   0.571688
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000
# std                       0.244173                   0.792680
#
#              reservation_status_date
# count                         118897
# mean   2016-07-30 07:39:51.289939968
# min              2014-10-17 00:00:00
# 25%              2016-02-02 00:00:00
# 50%              2016-08-08 00:00:00
# 75%              2017-02-09 00:00:00
# max              2017-09-14 00:00:00
# std                              NaN

# %%
plt.rc('font', size=12)
plt.rc('axes', labelcolor='#fff600')
plt.rc('text', color='#fff600')
plt.rc('xtick', color='#fff600')

myFig, ax = plt.subplots(figsize=(8, 6))
myFig.set_facecolor('#42ba00')

with sns.axes_style("whitegrid"):
    sns.boxplot(x=adr_outlier_removed['adr'], color='#1163ff', fliersize=5, linewidth=3, saturation=0.95, width=0.3, ax=ax)

plt.xlabel('Average Daily Rate (ADR)', labelpad=20)
plt.title('Box Plot: After Removing Outlier', fontsize=20, pad=20)

plt.show()

# %% [markdown]
# <a id="6"></a>
# <h1 style="background-color: #ffe500; font-size: 26px; color: #363021; text-align: center; font-family: Blogger Sans; font-weight: bold; margin: 10px; border: 1px solid; border-color: #363021; border-radius: 1px; padding: 15px; border-radius: 8px 8px 0 0;">6. Analysis and Findings</h1>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#     <span style="float: left; font-size: 60px; color: #42ba00; margin-right: 8px; margin-top: 18px;">N</span>ow, first of all, it is important to see the percentage of cancellation over the whole dataset. We can do it with the help of values_counts() function from pandas. It is used to get a series containing counts of unique values in a DataFrame column.
# </p>
# <ul style="margin: 12px 0px 0px 12px; font-size: 19px; font-weight: normal; font-family: Calibri; text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#     <li style="font-size: 18px; padding-bottom: 10px;">When <code style="background-color: lime;">normalize</code> is set to<span style="background-color: yellow;"> False (the default) </span>, the result will contain the counts of unique values in the specified column.</li>
#     <li style="font-size: 18px; padding-bottom: 10px;">When <code style="background-color: lime;">normalize</code> is set to<span style="background-color: yellow;"> True </span>, the result will contain the relative frequencies or percentages of each unique value in the specified column.</li>
#     </ul>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         The percentages are calculated by dividing the count of each unique value by the total number of non-null values in the column.
#     </p>
# </div>

# %%
cancellation_percentage = df['is_canceled'].value_counts(normalize = True)

# %%
cancellation_percentage
# Out:
# is_canceled
# 0    0.628648
# 1    0.371352
# Name: proportion, dtype: float64

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         In the above results, 0 represents the not-canceled ratio, while 1 represents the cancellation ratio. Let's extract the percentages for 0 and 1 to print the results separately, and visualize in plots for clear understanding.
#     </p>
# </div>

# %%
not_cancelled_percentage = cancellation_percentage[0] * 100
cancelled_percentage = cancellation_percentage[1] * 100

# %%
print(f"No-Cancellation Ratio: {not_cancelled_percentage:.2f}%")
print(f"Cancellation Ratio: {cancelled_percentage:.2f}%")
# Out:
# No-Cancellation Ratio: 62.86%
# Cancellation Ratio: 37.14%

# %% [markdown]
# <a id="6.1"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">6.1. Whole-over No-Cancellation Ratio vs Cancellation</h2>

# %%
plt.rc('font', size=12)
plt.rc('axes', labelcolor='#000000')
plt.rc('text', color='#000000')
plt.rc('xtick', color='#000000')

categories = ['No Cancellation Ratio', 'Cancellation Ratio']
cancel_ratio = [not_cancelled_percentage, cancelled_percentage]
colors = ['#1069e8', '#e81123']
width = 0.5

ax = sns.barplot(x=categories, y=cancel_ratio, palette=colors, saturation=width)

plt.xlabel('Categories', labelpad=20)
plt.ylabel('Percentages', labelpad=20)
plt.title('Fig 1: No-Cancellation Ratio vs Cancellation Ratio', fontsize=20, pad=20)

ax.set_facecolor("#ededed")

plt.show()

# %% [markdown]
# <a id="6.3"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">6.3. Hotel Specified No-Cancellation Ratio vs Cancellation</h2>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         The previous cancellation and no-cancellation ratio is based on the whole data. Now, let's extract and visualize on the basis of each hotel, to understand how much cancellation rate each one is facing.
#     </p>
# </div>

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.582911
# 1    0.417089
# Name: proportion, dtype: float64

# %%
city_hotel_ratio = city_hotel['is_canceled'].value_counts(normalize = True)
city_hotel_ratio
# Out:
# is_canceled
# 0    0.582911
# 1    0.417089
# Name: proportion, dtype: float64

# %%
city_hotel_cancellation_percentage = city_hotel_ratio[1] * 100
city_hotel_no_cancellation_percentage = city_hotel_ratio[0] * 100

# %%
print(f"City Hotel Cancellation Percentage: {city_hotel_cancellation_percentage: .2f}%")
print(f"City Hotel No-Cancellation Percentage: {city_hotel_no_cancellation_percentage: .2f}%")
# Out:
# City Hotel Cancellation Percentage:  41.71%
# City Hotel No-Cancellation Percentage:  58.29%

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
resort_hotel_ratio = resort_hotel['is_canceled'].value_counts(normalize = True)
resort_hotel_ratio
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
resort_hotel_cancellation_percentage = resort_hotel_ratio[1] * 100
resort_hotel_no_cancellation_percentage = resort_hotel_ratio[0] * 100

# %%
print(f"Resort Hotel Cancellation Percentage: {resort_hotel_cancellation_percentage: .2f}%")
print(f"Resort Hotel No-Cancellation Percentage: {resort_hotel_no_cancellation_percentage: .2f}%")
# Out:
# Resort Hotel Cancellation Percentage:  27.98%
# Resort Hotel No-Cancellation Percentage:  72.02%

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">Let's visualize it with a seaborn counts plot.</h2>

# %%
plt.rc('font', size=12)

plt.figure(figsize=(10, 6))

ax = sns.countplot(x='hotel', hue='is_canceled', data=df, palette=['#1069e8', '#e81123', '#19a01a', '#f3ba00'], width=0.7)
legend_labels, _ = ax.get_legend_handles_labels()
ax.legend(labels=['Not Canceled', 'Canceled'], bbox_to_anchor=(1, 1))

plt.title('Fig 2: No-Cancellation and Cancellation Ratio in Each Hotel', fontsize=20, pad=20)
plt.xlabel('Hotels Names', labelpad=20)
plt.ylabel('No-Cancellation / Cancellation Counts', labelpad=20)

ax.set_facecolor("#ededed")

plt.show()

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         We can also visualize both aspects separately using Pie charts. Let's do it.
#     </p>
# </div>

# %%
plt.rc('font', size=12)

labels = ['Cancellation', 'No-Cancellation']
colors = ['#19a01a', '#e81123']

plt.pie([city_hotel_cancellation_percentage, 
         city_hotel_no_cancellation_percentage], 
        labels=labels, autopct='%1.2f%%', colors=colors, startangle=90)

plt.title('Fig 3: City Hotel Cancellation Percentage VS No-Cancellation', fontsize=20, pad=20)
plt.axis('equal')

plt.show()

# %%
plt.rc('font', size=12)

labels = ['Cancellation', 'No-Cancellation']
colors = ['#19a01a', '#f3ba00']

plt.pie([resort_hotel_cancellation_percentage, 
         resort_hotel_no_cancellation_percentage], 
        labels=labels, autopct='%1.2f%%', colors=colors, startangle=90)

plt.title('Fig 4: Resort Hotel Cancellation Percentage VS No-Cancellation', fontsize=20, pad=20)
plt.axis('equal')

plt.show()

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         As we can see, resort hotels are experiencing a higher rate of reservation cancellations compared to city hotels.
#     </p>
# </div>

# %% [markdown]
# <a id="6.4"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">6.4. Comparing Prices of Both Hotels</h2>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Now, let's compare the prices of both city and resort hotels to observe which one has higher prices or which one is more expensive. Because prices can impact the reservation ratio.
#     </p>
# </div>

# %%
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">Let's visualize it with a wave plot.</h2>

# %%
plt.rc('font', size=18)

plt.figure(figsize=(20, 8))

plt.title('Fig 5: Average Daily Rate in City Hotel and Resort Hotel', fontsize=30, pad=30)
plt.xlabel('Months', labelpad=20)
plt.ylabel('Prices', labelpad=20)

plt.gca().set_facecolor('#19a01a')

plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel', color='#e81123')
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel', color='#f3ba00')

plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         In the above plot, there are spikes. We can consider that, these spikes are on the weekends. On the weekends, the prices of City Hotel and Resort Hotels become high.
#     </p>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         It also show that, in comparison to Resort Hotel, City Hotel have more bookings. It is possible that, Resort Hotels are more expensive than those in cities.
#     </p>
# </div>

# %% [markdown]
# <a id="6.5"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">6.5. Cancellation Rate on Monthly Basis</h2>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Now, let's observe the cancellation rate on monthly basis, to understand which month have high cancellation rate and which one is have lower cacellation rate.
#     </p>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#     For this purpose, we can use two columns:
#     <ol style="margin: 12px 0px 0px 12px; font-size: 19px; font-weight: normal; font-family: Calibri; text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         <li style="font-size: 18px; padding-bottom: 10px;">If we want to utilize months names, then we can chose already available column, <code style="background-color: lime;">arrival_date_month</code></li>
#         <li style="font-size: 18px; padding-bottom: 10px;">If we want to use numerical values, then we will need to derive a new column 'month' from <code style="background-color: lime;">reservation_status_date</code>column, with the help of <code style="background-color: lime;">dt.month</code> function.</li>
#     </ol>
# </div>

# %%
monthNames = df['arrival_date_month'].unique()
monthNames
# Out:
# array(['July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June'],
#       dtype=object)

# %%
df['month'] = df['reservation_status_date'].dt.month

# %%
df['month'].unique()
# Out:
# array([ 7,  5,  4,  6,  3,  8,  9,  1, 11, 10, 12,  2])

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">Let's visualize it with a seaborn counts plot.</h2>

# %%
plt.rc('font', size=12)

plt.figure(figsize=(16, 8))

ax = sns.countplot(x=df['arrival_date_month'], hue='is_canceled', data=df, palette=['#19a01a', '#e81123'], width=0.7)
legend_labels, _ = ax.get_legend_handles_labels()
ax.legend(labels=['No-Cancellation', 'Cancellation'], bbox_to_anchor=(1, 1))

plt.title('Fig 6: Monthly Reservation Counts', fontsize=20, pad=20)
plt.xlabel('Months', labelpad=20)
plt.ylabel('Reservation Counts', labelpad=20)

ax.set_facecolor("#ededed")

plt.show()

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Additionally, examining the average daily rate on a monthly basis can provide valuable insights.
#     </p>
# </div>

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">Let's visualize it with a bar plot.</h2>

# %%
plt.rc('font', size=12)

data = df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index()

plt.figure(figsize=(15, 8))

ax = sns.barplot(x=monthNames, y='adr', data=data, 
            palette=['#e81123', '#420050', '#f3ba00', '#0d0060', '#19a01a', '#0d0060', '#1163ff'])

plt.title("Fig 7: Monthly Average Daily Rate", fontsize=20, pad=20)
plt.xlabel('Months', labelpad=20)
plt.ylabel('Average Daily Rate', labelpad=20)

plt.legend(fontsize=20)

ax.set_facecolor("#ededed")

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <a id="6.5"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">6.5. Cancellation Rate on The Basis of Countries (Top 5)</h2>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Let's to observe the cacellation ratio on the basis of countries. We will extract top 5 contries with high cancellation ratio.
#     </p>
# </div>

# %%
cancelled_data = df[df['is_canceled'] == 1]
top_5_countries = cancelled_data['country'].value_counts()[:5]

# %%
top_5_countries
# Out:
# country
# PRT    27515
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">Let's visualize it with a Pie chart.</h2>

# %%
plt.rc('font', size=12)

colors = ['#e81123', '#420050', '#1163ff', '#0d0060', '#f3ba00']

plt.figure(figsize=(8, 8))
plt.title('Fig 8: Top 5 Countries with High Cancellation Ratio', fontsize=20, pad=20)
plt.pie(top_5_countries, autopct='%1.2f%%', labels=top_5_countries.index, colors=colors, 
        startangle=90)

plt.show()

# %% [markdown]
# <a id="6.6"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">6.6. Market Segment Ratio Observation</h2>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Now, as we mentioned in our hypothesis: "The majority of clients are coming from offline travel agents to make their reservations."
#     </p>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Let's confirm whether our hypothesis is right or wrong. We can do this by observing the percentage of the market segment feature with the help of the <code style="background-color: lime;">value_counts()</code> function.
#         </p>
# </div>

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24160
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
market_segment_ratio_overall = df['market_segment'].value_counts(normalize=True)*100
market_segment_ratio_overall
# Out:
# market_segment
# Online TA        47.437299
# Offline TA/TO    20.319938
# Groups           16.657976
# Direct           10.469478
# Corporate         4.298643
# Complementary     0.617336
# Aviation          0.199331
# Name: proportion, dtype: float64

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">For more better understanding, we can visualize it in a Bar Plot.</h2>

# %%
plt.rc('font', size=12)

colors = ['#19a01a', '#420050', '#f3ba00', '#0d0060', '#e81123', '#0d0060', '#1163ff']

fig, ax = plt.subplots(figsize=(12, 6))

# Assuming df is your DataFrame and 'market_segment' is a valid column
ax.bar(x=df['market_segment'].value_counts().index, height=df['market_segment'].value_counts(), color=colors)

plt.title('Fig 9: Customers Market Segment Ratio', fontsize=20, pad=20)
plt.xlabel('Sources', labelpad=25)
plt.ylabel('Market Segment Ratio (%)', labelpad=25)

ax.set_facecolor("#ededed")

plt.show()

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         As we can see, the majority of clients (47.437%) are coming from online sources. However, we initially asserted that the majority of clients come from offline sources. Hence, our hypothesis was incorrect.
#     </p>
# </div>

# %% [markdown]
# <a id="6.6"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">6.7. Market Segment Ratio vs Cancellation Ratio</h2>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Now, let's compare this market segment ratio with the cancellation ratio to observe which customers' source has the highest cancellation rate.
#     </p>
# </div>

# %%
cancelled_data['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        20738
# Groups           12097
# Offline TA/TO     8278
# Direct            1920
# Corporate          978
# Complementary       90
# Aviation            52
# Name: count, dtype: int64

# %%
market_segment_ratio_cancelled = cancelled_data['market_segment'].value_counts(normalize=True)*100
market_segment_ratio_cancelled
# Out:
# market_segment
# Online TA        46.968496
# Groups           27.397912
# Offline TA/TO    18.748443
# Direct            4.348515
# Corporate         2.215025
# Complementary     0.203837
# Aviation          0.117772
# Name: proportion, dtype: float64

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">For more better understanding, we can visualize it in a Pie.</h2>

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=12)

colors = ['#19a01a', '#420050', '#f3ba00', '#0d0060', '#e81123', '#0d0060', '#1163ff']

fig, ax = plt.subplots(figsize=(12, 6))

ax.bar(x=market_segment_ratio_cancelled.index, height=market_segment_ratio_cancelled.values, color=colors)

plt.title('Fig 9: Customers Market Segment Ratio', fontsize=20, pad=20)
plt.xlabel('Sources', labelpad=25)
plt.ylabel('Market Segment Ratio (%)', labelpad=25)

ax.set_facecolor("#ededed")

plt.show()

# %%
# Count cancellations per market segment
cancellation_counts = df[df['is_canceled'] == 1]['market_segment'].value_counts()

# Calculate cancellation ratio per market segment
cancellation_ratio_per_segment = (cancellation_counts / df['market_segment'].value_counts()) * 100

# Overall cancellation ratio
overall_cancellation_ratio = (df[df['is_canceled'] == 1].shape[0] / df.shape[0]) * 100

# Print cancellation ratios
print("Cancellation Ratios per Market Segment:")
print(cancellation_ratio_per_segment)
print("\nOverall Cancellation Ratio:", overall_cancellation_ratio)
# Out:
# Cancellation Ratios per Market Segment:
# market_segment
# Aviation         21.940928
# Complementary    12.261580
# Corporate        19.135199
# Direct           15.424165
# Groups           61.077451
# Offline TA/TO    34.263245
# Online TA        36.768200
# Name: count, dtype: float64
#
# Overall Cancellation Ratio: 37.13519150868812

# %% [markdown]
# <a id="6.8"></a>
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; border-bottom: 5px solid #e81123; border-radius: 5px; padding-bottom: 20px;">6.8. Comparing Prices Trends of Cancellation and No-Cancellation</h2>

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Now, let's investigate the range of prices for both canceled reservations and non-canceled reservations. This analysis will help us confirm whether the highest prices are impacting the reservation ratio.
#     </p>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         For this purpose, we can examine the average daily rate (ADR) in both cancelled and non-cancelled reservations.
#     </p>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Let's filter for no-cancellation data.
#     </p>
# </div>

# %%
no_cancellation_data = df[df['is_canceled'] == 0]

# %%
no_cancellation_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
# 3                        0                     1       1  ...
# 4                        0                     2       2  ...
#
#    booking_changes  deposit_type days_in_waiting_list customer_type   adr  \
# 0                3    No Deposit                    0     Transient   0.0
# 1                4    No Deposit                    0     Transient   0.0
# 2                0    No Deposit                    0     Transient  75.0
# 3                0    No Deposit                    0     Transient  75.0
# 4                0    No Deposit                    0     Transient  98.0
#
#   required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                           0                          0           Check-Out
# 1                           0                          0           Check-Out
# 2                           0                          0           Check-Out
# 3                           0                          0           Check-Out
# 4                           0                          1           Check-Out
#
#    reservation_status_date month
# 0               2015-07-01     7
# 1               2015-07-01     7
# 2               2015-07-02     7
# 3               2015-07-02     7
# 4               2015-07-03     7
#
# [5 rows x 31 columns]

# %%
no_cancellation_prices = no_cancellation_data.groupby('reservation_status_date')[['adr']].mean()
no_cancellation_prices.reset_index(inplace=True)
no_cancellation_prices.sort_values('reservation_status_date', inplace=True)

# %%
no_cancellation_prices.head()
# Out:
#   reservation_status_date         adr
# 0              2015-07-01   31.650000
# 1              2015-07-02   95.924000
# 2              2015-07-03   97.645205
# 3              2015-07-04  110.480000
# 4              2015-07-05  100.308485

# %%
no_cancellation_data = df[df['is_canceled'] == 0]

no_cancellation_data.head()

no_cancellation_prices = no_cancellation_data.groupby('reservation_status_date')[['adr']].mean()
no_cancellation_prices.reset_index(inplace=True)
no_cancellation_prices.sort_values('reservation_status_date', inplace=True)

no_cancellation_prices.head()
# Out:
#   reservation_status_date         adr
# 0              2015-07-01   31.650000
# 1              2015-07-02   95.924000
# 2              2015-07-03   97.645205
# 3              2015-07-04  110.480000
# 4              2015-07-05  100.308485

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         Also, filter for cancellation data.
#     </p>
# </div>

# %%
cancellation_data = df[df['is_canceled'] == 1]

# %%
cancellation_data.head()
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 27  Resort Hotel            1         60               2015
# 32  Resort Hotel            1         96               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 8                July                        27                          1
# 9                July                        27                          1
# 10               July                        27                          1
# 27               July                        27                          1
# 32               July                        27                          1
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 8                         0                     3       2  ...
# 9                         0                     3       2  ...
# 10                        0                     4       2  ...
# 27                        2                     5       2  ...
# 32                        2                     8       2  ...
#
#     booking_changes  deposit_type days_in_waiting_list customer_type    adr  \
# 8                 0    No Deposit                    0     Transient   82.0
# 9                 0    No Deposit                    0     Transient  105.5
# 10                0    No Deposit                    0     Transient  123.0
# 27                0    No Deposit                    0     Transient  107.0
# 32                0    No Deposit                    0     Transient  108.3
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 8                            0                          1            Canceled
# 9                            0                          0            Canceled
# 10                           0                          0            Canceled
# 27                           0                          2            Canceled
# 32                           0                          2            Canceled
#
#     reservation_status_date month
# 8                2015-05-06     5
# 9                2015-04-22     4
# 10               2015-06-23     6
# 27               2015-05-11     5
# 32               2015-05-29     5
#
# [5 rows x 31 columns]

# %%
cancellation_prices = cancellation_data.groupby('reservation_status_date')[['adr']].mean()
cancellation_prices.reset_index(inplace=True)
cancellation_prices.sort_values('reservation_status_date', inplace=True)

# %%
cancellation_prices.head()
# Out:
#   reservation_status_date        adr
# 0              2014-10-17  62.800000
# 1              2014-11-18   0.000000
# 2              2015-01-01  62.062779
# 3              2015-01-02   9.633750
# 4              2015-01-18   0.000000

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">For more clear understanding, let's visualize it in a wave graph.</h2>

# %%
plt.rc('font', size=18)

plt.figure(figsize=(20, 8))

plt.gca().set_facecolor('#19a01a')

plt.plot(no_cancellation_prices['reservation_status_date'], 
         no_cancellation_prices['adr'], label='Non-Cancelled Prices', color='#f3ba00')

plt.plot(cancellation_prices['reservation_status_date'], 
         cancellation_prices['adr'], label='Cancelled Prices', color='#e81123')

plt.title('Fig 9: Average Daily Rate', fontsize=30, pad=30)
plt.xlabel('Timeperiod', labelpad=20)
plt.ylabel('Prices', labelpad=20)

plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# <div style="position: relative; background-color: #fff7f7; border: 2px solid #1163ff; border-radius: 2px; padding : 20px; margin: 30px 10px 30px 10px; font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #0d4987;">
#     <div style="position: absolute; top: -20px; left: 15%; transform: translateX(-50%); background-color: #1163ff; padding: 5px 15px; font-weight: bold; font-size: 20px; color: #ededed;">&#128221; Note Pad</div>
#     <p style="font-size: 18px; font-weight: normal; font-family: Calibri (Body); text-align: justify; line-height: 30px; letter-spacing: 1px; color: #42ba00;">
#         In the above wave graph, it's evident that the waves exhibit distinct patterns, and the data appears to be spread out. This spread is causing inconsistency in current data. To address this and enhance consistency, let's filter and utilize the data between September 2015 and September 2017.
#     </p>
# </div>

# %%
cancellation_prices_filtered = cancellation_prices[
    (cancellation_prices['reservation_status_date']>'2015-09')
    & (cancellation_prices['reservation_status_date']<'2017-09')]

no_cancellation_prices_filtered = no_cancellation_prices[
    (no_cancellation_prices['reservation_status_date']>'2015-09')
    & (no_cancellation_prices['reservation_status_date']<'2017-09')]

# %% [markdown]
# <h2 style="font-family: Calibri (Body); font-size: 24px; font-weight: bold; text-shadow: 0 0 8px #ededed; text-decoration: none; text-transform: none; margin-bottom: 0em; letter-spacing: 2px; color: #1163ff; background-color: #ffffff; padding-bottom: 20px;">Now, after filtering the data, let's re-visualize the wave graph.</h2>

# %%
plt.rc('font', size=18)

plt.figure(figsize=(20, 8))

plt.gca().set_facecolor('#19a01a')

plt.plot(no_cancellation_prices_filtered['reservation_status_date'], 
         no_cancellation_prices_filtered['adr'], label='Non-Cancelled Prices', color='#f3ba00')

plt.plot(cancellation_prices_filtered['reservation_status_date'], 
         cancellation_prices_filtered['adr'], label='Cancelled Prices', color='#e81123')

plt.title('Fig 14: Average Daily Rate', fontsize=30, pad=30)
plt.xlabel('Timeperiod', labelpad=20)
plt.ylabel('Prices', labelpad=20)

plt.legend(fontsize=20)
plt.show()
